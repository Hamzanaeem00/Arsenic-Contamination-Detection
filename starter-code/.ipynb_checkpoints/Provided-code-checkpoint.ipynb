# %%
pip install epyt_flow
# Out:
# Collecting epyt_flow
#   Downloading epyt_flow-0.17.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting epanet-plus>=0.3.0 (from epyt_flow)
#   Downloading epanet_plus-0.3.1-cp313-cp313-macosx_15_0_arm64.whl.metadata (5.7 kB)
# Requirement already satisfied: requests>=2.31.0 in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (2.34.2)
# Requirement already satisfied: scipy>=1.11.4 in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (1.16.3)
# Collecting u-msgpack-python>=2.8.0 (from epyt_flow)
#   Downloading u_msgpack_python-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: networkx>=3.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (3.5)
# Requirement already satisfied: scikit-learn>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (1.7.2)
# Requirement already satisfied: tqdm>=4.66.2 in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (4.67.1)
# Requirement already satisfied: openpyxl>=3.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (3.1.5)
# Collecting falcon>=3.1.3 (from epyt_flow)
#   Downloading falcon-4.3.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (37 kB)
# Collecting multiprocess>=0.70.16 (from epyt_flow)
#   Downloading multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# Collecting geopandas>=0.14.4 (from epyt_flow)
#   Downloading geopandas-1.1.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting svgpath2mpl>=1.0.0 (from epyt_flow)
#   Downloading svgpath2mpl-1.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting Deprecated>=1.2.14 (from epyt_flow)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.13/site-packages (from epyt_flow) (7.0.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/anaconda3/lib/python3.13/site-packages (from Deprecated>=1.2.14->epyt_flow) (1.17.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from epanet-plus>=0.3.0->epyt_flow) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas>=0.14.4->epyt_flow)
#   Downloading pyogrio-0.13.0-cp311-abi3-macosx_12_0_arm64.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from geopandas>=0.14.4->epyt_flow) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from geopandas>=0.14.4->epyt_flow) (2.3.3)
# Collecting pyproj>=3.5.0 (from geopandas>=0.14.4->epyt_flow)
#   Downloading pyproj-3.7.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas>=0.14.4->epyt_flow)
#   Downloading shapely-2.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting dill>=0.4.1 (from multiprocess>=0.70.16->epyt_flow)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: et_xmlfile in /opt/anaconda3/lib/python3.13/site-packages (from openpyxl>=3.1.2->epyt_flow) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas>=0.14.4->epyt_flow) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas>=0.14.4->epyt_flow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas>=0.14.4->epyt_flow) (2025.2)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas>=0.14.4->epyt_flow) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas>=0.14.4->epyt_flow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.31.0->epyt_flow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.31.0->epyt_flow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.31.0->epyt_flow) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.4.0->epyt_flow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.4.0->epyt_flow) (3.5.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (from svgpath2mpl>=1.0.0->epyt_flow) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->svgpath2mpl>=1.0.0->epyt_flow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->svgpath2mpl>=1.0.0->epyt_flow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->svgpath2mpl>=1.0.0->epyt_flow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->svgpath2mpl>=1.0.0->epyt_flow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->svgpath2mpl>=1.0.0->epyt_flow) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->svgpath2mpl>=1.0.0->epyt_flow) (3.2.5)
# Downloading epyt_flow-0.17.2-py3-none-any.whl (244 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading epanet_plus-0.3.1-cp313-cp313-macosx_15_0_arm64.whl (855 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 855.9/855.9 kB 18.4 MB/s  0:00:00
# Downloading falcon-4.3.1-cp313-cp313-macosx_11_0_arm64.whl (425 kB)
# Downloading geopandas-1.1.4-py3-none-any.whl (343 kB)
# Downloading multiprocess-0.70.19-py313-none-any.whl (156 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading pyogrio-0.13.0-cp311-abi3-macosx_12_0_arm64.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 15.8 MB/s  0:00:01 eta 0:00:01
# Downloading pyproj-3.7.2-cp313-cp313-macosx_14_0_arm64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 21.0 MB/s  0:00:00 eta 0:00:01
# Downloading shapely-2.1.2-cp313-cp313-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 38.8 MB/s  0:00:00
# Downloading svgpath2mpl-1.0.0-py2.py3-none-any.whl (7.8 kB)
# Downloading u_msgpack_python-2.8.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: u-msgpack-python, shapely, pyproj, pyogrio, falcon, epanet-plus, dill, Deprecated, multiprocess, svgpath2mpl, geopandas, epyt_flow
#   Attempting uninstall: dill0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [falcon]]
#     Found existing installation: dill 0.4.0━━━━━━━━━━━━━━━━━━━  4/12 [falcon]
#     Uninstalling dill-0.4.0:━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [falcon]
#       Successfully uninstalled dill-0.4.0━━━━━━━━━━━━━━━━━━━━━  4/12 [falcon]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [epyt_flow]12 [epyt_flow]
# Successfully installed Deprecated-1.3.1 dill-0.4.1 epanet-plus-0.3.1 epyt_flow-0.17.2 falcon-4.3.1 geopandas-1.1.4 multiprocess-0.70.19 pyogrio-0.13.0 pyproj-3.7.2 shapely-2.1.2 svgpath2mpl-1.0.0 u-msgpack-python-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from epyt_flow.data.benchmarks import load_leakdb_scenarios
from epyt_flow.simulation import ScenarioSimulator, EpanetConstants, ScenarioConfig
from epyt_flow.simulation.events import SpeciesInjectionEvent
from epyt_flow.utils import to_seconds
import epyt_flow.data.benchmarks as benchmarks


if __name__ == "__main__":
    # Create a new scenario based on the first Net1 LeakDB scenario --
    # we add an additional EPANET-MSX configuration file
    config, = load_leakdb_scenarios(scenarios_id=["1"], use_net1=True)
    config = ScenarioConfig(scenario_config=config,
                            f_msx_in="arsenic_contamination.msx")

    with ScenarioSimulator(scenario_config=config) as sim:
        # Set simulation duration to 21 days
        sim.set_general_parameters(simulation_duration=to_seconds(days=21))

        # Place some chlorine sensors and also keep track of the contaminant
        cl_sensor_locations = ["10", "11", "12", "13", "21", "22", "23", "31", "32"]
        all_nodes = sim.sensor_config.nodes
        sim.set_bulk_species_node_sensors({"Chlorine": cl_sensor_locations,
                                           # Also: Keep track of the contaminant
                                           "AsIII": all_nodes})   # Arsenite

        # Create a 1-day contamination event --
        # i.e. injection of Arsenite (100mg/L) at node "22"
        contamination_event = SpeciesInjectionEvent(species_id="AsIII", node_id="22",
                                                    profile=np.array([100]),
                                                    source_type=EpanetConstants.EN_MASS,
                                                    start_time=to_seconds(days=3),
                                                    end_time=to_seconds(days=4))
        sim.add_system_event(contamination_event)

        # Run simulation
        scada_data = sim.run_simulation()
        flows = scada_data.get_data_flows()

        print(type(flows))
        print()

        print(flows)
        chlorine = scada_data.get_data_bulk_species_node_concentration({"Chlorine": cl_sensor_locations})

        print(type(chlorine))
        print()

        print(chlorine)

        df = scada_data.to_pandas_dataframe()

        print(scada_data.sensor_readings_time[:10])
        print(len(scada_data.sensor_readings_time))
        print(scada_data.sensor_readings_time[-1])

        # Inspect simulation results -- i.e. sensor readings over time
        scada_data.plot_bulk_species_node_concentration({"Chlorine": cl_sensor_locations})
        scada_data.plot_bulk_species_node_concentration({"AsIII": all_nodes})



print(dir(benchmarks))
